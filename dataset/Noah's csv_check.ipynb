# %%
import pandas as pd
import numpy as np
#import matplotlib as plt
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("data1.csv")
data1['date'] = data1['date'].apply(lambda x: x.split(',')[1])
data1.sort_values("userscore", axis = 0, ascending = False, inplace = True)
data1 = data1[data1.userscore != "tbd"]
data1.set_index(["userscore"], inplace = True)
data1
# Out:
#            metascore                                          name console  \
# userscore
# 9.4               89                      Final Fantasy Chronicles      PS
# 9.3               93                      The Witcher 3: Wild Hunt      PC
# 9.3               74                         The Legend of Dragoon      PS
# 9.3               91                                 Resident Evil      GC
# 9.3               87                   Bloodborne: The Old Hunters     PS4
# 9.3               96                               Resident Evil 4      GC
# 9.3               92                      Final Fantasy VI Advance     GBA
# 9.2               94                              Final Fantasy IX      PS
# 9.2               95              Baldur's Gate II: Shadows of Amn      PC
# 9.2               90                                        Portal      PC
# 9.2               84                                      Vanquish    X360
# ...

# %%
data2 = pd.read_csv("data2.csv")
# for data2
# drop publisher 
# drop genre
# change year to int
# drop rating
# drop user < 50 and critic < 10 count
# drop developer
# drop global sales < 0.1 m

# data2['Year_of_Release'] = data2['Year_of_Release'].fillna(0).apply(np.int64)
# data2['Critic_Count'] = data2['Critic_Count'].fillna(0).apply(np.int64)
# data2['User_Count'] = data2['User_Count'].fillna(0).apply(np.int64)
# print(data2.User_Count[10827]< 50)
# print(data2.Critic_Count[10827] < 10)
# print((data2.Critic_Count[10827] < 10) or (data2.User_Count[10827] < 50))
# print(data2.loc[ 10827 , : ])
# for i in range(16719):
#     if data2.Global_Sales[i] < 0.1:
#         data2 = data2.drop(i,axis = 0)
#     if not((data2.Critic_Count[i] < 10) and (data2.User_Count[i] < 50)):
#         data2 = data2.drop(i,axis = 0)
data2
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
data2 = data2.drop('Publisher',axis = 1)
data2 = data2.drop('Genre',axis = 1)
data2 = data2.drop('Rating',axis = 1)
data2 = data2.drop('Developer',axis = 1)
data2 = data2.drop('Platform',axis = 1)
data2 = data2.drop('Year_of_Release',axis = 1)
data2 = data2.drop('NA_Sales',axis = 1)
data2 = data2.drop('EU_Sales',axis = 1)
data2 = data2.drop('JP_Sales',axis = 1)
data2 = data2.drop('Other_Sales',axis = 1)
data2 = data2.drop('Critic_Count',axis = 1)
data2 = data2.drop('User_Count',axis = 1)

# %%
data3 = pd.read_csv("data3Revised.csv")
data3
# Out:
#        Unnamed: 0                                              title  \
# 0               0                                     Wii Sports
# 1               1                              Super Mario Bros.
# 2               2                                 Mario Kart Wii
# 3               3                  PlayerUnknown's Battlegrounds
# 4               4                              Wii Sports Resort
# 5               5             Pokémon Red / Green / Blue Version
# 6               6                          New Super Mario Bros.
# 7               7                      New Super Mario Bros. Wii
# 8               8                                         Tetris
# 9               9                                      Minecraft
# 10             10                                      Duck Hunt
# 11             11                                       Wii Play
# 12             12                             Kinect Adventures!
# ...

# %%
data3 = data3.rename({'jp_sale':'keydata'}, axis = 1)

# %%
data1=data1.rename(columns = {'name':'title'})
data2 = data2.rename(columns = {'Name':'title'})

# %%
data3 = data3.drop('other_sale', axis = 1)

# %%
data2.rename(columns = {'User_Score':'user_Score'})
combo = pd.merge(data1, data2, on='title', how='inner', indicator=True)
combo = combo.drop(combo[combo.User_Score=='tbd'].index)
combo = combo.dropna()

# %%
# combo.loc[:,'User_Score']*=10
combo['User_Score']=pd.to_numeric(combo['User_Score'])
combo['User_Score']=combo['User_Score']*10
# for a in range (0, 17217):
#     user

# %%
combo = combo.drop('Critic_Score', axis = 1)
combo = combo.drop('_merge', axis = 1)
combo = combo.reset_index()

# %%
for a in range (1,14276):
    if combo['title'][a] == combo['title'][a-1] and combo['console'][a]==combo['console'][a-1]:
        combo = combo.drop(a-1, axis = 0)

# %%
combo = combo.reset_index()
combo
# Out:
#       level_0  index  metascore                                title console  \
# 0           0      0         89             Final Fantasy Chronicles      PS
# 1           3      3         93             The Witcher 3: Wild Hunt      PC
# 2           6      6         91             The Witcher 3: Wild Hunt    XONE
# 3           9      9         92             The Witcher 3: Wild Hunt     PS4
# 4          10     10         74                The Legend of Dragoon      PS
# 5          11     11         91                        Resident Evil      GC
# 6          14     17         96                      Resident Evil 4      GC
# 7          17     21         96                      Resident Evil 4     PS2
# 8          20     25         82                      Resident Evil 4     PS4
# 9          23     29         76                      Resident Evil 4    XONE
# 10         26     33         76                      Resident Evil 4      PC
# ...

# %% [markdown]
# # Plot_1
# ## Below plot is metascore against millions of sales vs user score against millions of sales.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (48,16)) 
ax[0].scatter(combo["metascore"], combo["Global_Sales"], alpha= 0.5)
ax[1].scatter(combo["User_Score"], combo["Global_Sales"], alpha= 0.5)
fig.suptitle("Reviews vs Sales", fontsize = 56, fontweight = "bold")

ax[0].set_title("Metascore v sales", fontsize = 36) 
ax[1].set_title("userscore v sales", fontsize = 36)
for var in ax:
    var.set_ylim(0,1)
    var.set_ylabel("Millions of sales", fontsize = 36)
ax[0].set_xlabel("Metascore", fontsize = 36)
ax[1].set_xlabel("User score", fontsize =36)
ax[0].set_xlim((100))
# plt.xticks(rotation = 90)
ax[1].set_xlim((10))
# plt.xticks(rotation = 30)
# for label in ax[1].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[1].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
# for label in ax[0].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[0].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
plt.show()

# %%
fig, ax1 = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (48,16)) 
ax1[0].scatter(combo["metascore"], combo["Global_Sales"], alpha= 0.5)
ax1[1].scatter(combo["User_Score"], combo["Global_Sales"], alpha= 0.5)
fig.suptitle("Reviews vs Sales", fontsize = 56, fontweight = "bold")

ax1[0].set_title("Metascore v sales", fontsize = 36) 
ax1[1].set_title("userscore v sales", fontsize = 36)
for var in ax1:
    var.set_ylim(0,2)
    var.set_ylabel("Millions of sales", fontsize = 36)
ax1[0].set_xlabel("Metascore", fontsize = 36)
ax1[1].set_xlabel("User score", fontsize =36)
ax1[0].set_xlim((100))
# plt.xticks(rotation = 90)
ax1[1].set_xlim((10))
# plt.xticks(rotation = 30)
# for label in ax[1].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[1].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
# for label in ax[0].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[0].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
plt.show()

# %%
fig, ax2 = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (48,16)) 
ax2[0].scatter(combo["metascore"], combo["Global_Sales"], alpha= 0.5)
ax2[1].scatter(combo["User_Score"], combo["Global_Sales"], alpha= 0.5)
fig.suptitle("Reviews vs Sales", fontsize = 56, fontweight = "bold")

ax2[0].set_title("Metascore v sales", fontsize = 36) 
ax2[1].set_title("userscore v sales", fontsize = 36)
for var in ax2:
    var.set_ylim(0,3)
    var.set_ylabel("Millions of sales", fontsize = 36)
ax2[0].set_xlabel("Metascore", fontsize = 36)
ax2[1].set_xlabel("User score", fontsize =36)
ax2[0].set_xlim((100))
# plt.xticks(rotation = 90)
ax2[1].set_xlim((10))
# plt.xticks(rotation = 30)
# for label in ax[1].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[1].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
# for label in ax[0].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[0].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
plt.show()

# %%
fig, ax3 = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (48,16)) 
ax3[0].scatter(combo["metascore"], combo["Global_Sales"], alpha= 0.5)
ax3[1].scatter(combo["User_Score"], combo["Global_Sales"], alpha= 0.5)
fig.suptitle("Reviews vs Sales", fontsize = 56, fontweight = "bold")

ax3[0].set_title("Metascore v sales", fontsize = 36) 
ax3[1].set_title("userscore v sales", fontsize = 36)
for var in ax3:
    var.set_ylim(0,34)
    var.set_ylabel("Millions of sales", fontsize = 36)
ax3[0].set_xlabel("Metascore", fontsize = 36)
ax3[1].set_xlabel("User score", fontsize =36)
ax3[0].set_xlim((100))
# plt.xticks(rotation = 90)
ax3[1].set_xlim((10))
# plt.xticks(rotation = 30)
# for label in ax[1].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[1].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
# for label in ax[0].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[0].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
plt.show()

# %%
fig, ax4 = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (48,16)) 
ax4[0].scatter(combo["metascore"], combo["Global_Sales"], alpha= 0.5)
ax4[1].scatter(combo["User_Score"], combo["Global_Sales"], alpha= 0.5)
fig.suptitle("Reviews vs Sales", fontsize = 56, fontweight = "bold")

ax4[0].set_title("Metascore v sales", fontsize = 36) 
ax4[1].set_title("userscore v sales", fontsize = 36)
for var in ax4:
    var.set_ylim(0,4)
    var.set_ylabel("Millions of sales", fontsize = 36)
ax4[0].set_xlabel("Metascore", fontsize = 36)
ax4[1].set_xlabel("User score", fontsize =36)
ax4[0].set_xlim((100))
# plt.xticks(rotation = 90)
ax4[1].set_xlim((10))
# plt.xticks(rotation = 30)
# for label in ax[1].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[1].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
# for label in ax[0].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[0].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
plt.show()

# %%
fig, ax5 = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (48,16)) 
ax5[0].scatter(combo["metascore"], combo["Global_Sales"], alpha= 0.5)
ax5[1].scatter(combo["User_Score"], combo["Global_Sales"], alpha= 0.5)
fig.suptitle("Reviews vs Sales", fontsize = 56, fontweight = "bold")

ax5[0].set_title("Metascore v sales", fontsize = 36) 
ax5[1].set_title("userscore v sales", fontsize = 36)
for var in ax5:
    var.set_ylim(0,2)
    var.set_ylabel("Millions of sales", fontsize = 36)
ax5[0].set_xlabel("Metascore", fontsize = 36)
ax5[1].set_xlabel("User score", fontsize =36)
ax5[0].set_xlim((100))
# plt.xticks(rotation = 90)
ax5[1].set_xlim((10))
# plt.xticks(rotation = 30)
# for label in ax[1].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[1].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
# for label in ax[0].get_xaxis().get_ticklabels()[::1]:
#     label.set_visible(False)
# for label in ax[0].get_xaxis().get_ticklabels()[::20]:
#     label.set_visible(True)
plt.show()
