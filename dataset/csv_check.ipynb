# %%
import pandas as pd

# %%
data1 = pd.read_csv("data1.csv")
print(data1)
data1['date'] = data1['date'].apply(lambda x: x.split(',')[1])
data1.sort_values("userscore", axis = 0, ascending = False, inplace = True)
data1 = data1[data1.userscore != "tbd"]
data1.set_index(["userscore"], inplace = True)
data1
# Out:
#        metascore                                        name console  \
# 0             97                          Grand Theft Auto V     PS3
# 1             97                          Grand Theft Auto V    X360
# 2             95                              The Last of Us     PS3
# 3             94                           BioShock Infinite     PS3
# 4             94                           BioShock Infinite      PC
# 5             93                           BioShock Infinite    X360
# 6             93                        Super Mario 3D World    WIIU
# 7             92                      Fire Emblem: Awakening     3DS
# 8             92                              Rayman Legends    WIIU
# 9             91                                         Fez      PC
# 10            91                              Rayman Legends     PS3
# 11            91  The Legend of Zelda: A Link Between Worlds     3DS
# 12            91                                      flower     PS4
# ...

# %%
data2 = pd.read_csv("data2.csv")
data2.sort_values("Year_of_Release", axis = 0, )
data2
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
data3 = pd.read_csv("data3.csv")
data3
# Out:
#                                                    title user_Score  \
# 0                                         Wii Sports          N/A
# 1                                  Super Mario Bros.            8.2
# 2                                     Mario Kart Wii            9.1
# 3                      PlayerUnknown's Battlegrounds          N/A
# 4                                  Wii Sports Resort            8.8
# 5                 Pokémon Red / Green / Blue Version          N/A
# 6                              New Super Mario Bros.            8.1
# 7                          New Super Mario Bros. Wii            9.2
# 8                                             Tetris          N/A
# 9                                          Minecraft          N/A
# 10                                         Duck Hunt          N/A
# 11                                          Wii Play            4.5
# 12                                Kinect Adventures!          N/A
# ...

# %%
data2.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# critic = 0
# user = 0
# print(data2.Critic_Score[119])
# print(data2.User_Score[119])
# for i in range(16719):
#     if  not(pd.isna(data2.Critic_Score[i]) and pd.isna(data2.User_Score[i])):
#         if float(data2.Critic_Score[i]) < (float(data2.User_Score[i])*10):
#             critic+=1
#         elif float(data2.Critic_Score[i]) < (float(data2.User_Score[i])*10):
#             user+=1
# if critic > user:
#     print('Critic')
# elif critic < user:
#     print('User')

# %%
count = 0
for i in range(16719):
    if pd.isna(data2.Critic_Score[i]) and pd.isna(data2.User_Score[i]):
        count+=1
count
# Out:
# 6666
