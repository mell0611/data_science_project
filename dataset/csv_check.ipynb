# %%
import pandas as pd

# %%
data1 = pd.read_csv("data1.csv")
data1.set_index("userscore")
# Out:
#            metascore                                        name console  \
# userscore
# 8.3               97                          Grand Theft Auto V     PS3
# 8.3               97                          Grand Theft Auto V    X360
# 9.2               95                              The Last of Us     PS3
# 8.5               94                           BioShock Infinite     PS3
# 8.6               94                           BioShock Infinite      PC
# 8.5               93                           BioShock Infinite    X360
# 8.9               93                        Super Mario 3D World    WIIU
# 9.1               92                      Fire Emblem: Awakening     3DS
# 8.7               92                              Rayman Legends    WIIU
# 6.7               91                                         Fez      PC
# 8.7               91                              Rayman Legends     PS3
# 9                 91  The Legend of Zelda: A Link Between Worlds     3DS
# ...
